# %%
import pandas as pd
import numpy as np
import matplotlib
import seaborn as sns
import matplotlib.pyplot as plt

# %%
obesity_dt = pd.read_csv('CDC_Obesity_Data.csv')
list(obesity_dt)
# Out:
# ['YearStart',
#  'YearEnd',
#  'LocationAbbr',
#  'LocationDesc',
#  'Datasource',
#  'Class',
#  'Topic',
#  'Question',
#  'Data_Value_Unit',
#  'Data_Value_Type',
#  'Data_Value',
#  'Data_Value_Alt',
#  'Data_Value_Footnote_Symbol',
#  'Data_Value_Footnote',
#  'Low_Confidence_Limit',
#  'High_Confidence_Limit ',
#  'Sample_Size',
#  'Total',
#  'Age(years)',
#  'Education',
#  'Gender',
#  'Income',
#  'Race/Ethnicity',
#  'GeoLocation',
#  'ClassID',
#  'TopicID',
#  'QuestionID',
#  'DataValueTypeID',
#  'LocationID',
#  'StratificationCategory1',
#  'Stratification1',
#  'StratificationCategoryId1',
#  'StratificationID1']

# %% [markdown]
# # Problem 1: What does A equal in the expression X LaTeX: \in ∈  A?

# %%
len(obesity_dt['Question'].unique())
# Out:
# 9

# %% [markdown]
# "A" is a unique set of values and "X" is an element of "A". In this case, "A" = 9 because there are 9 unique instances of X.

# %% [markdown]
# # Problem 2:

# %% [markdown]
# B = "for all" of values of Y, calculate the sum of all Y instances

# %%
print(obesity_dt['Data_Value'].sum())
# Out:
# 1506300.8999999964

# %% [markdown]
# # Problem 3:

# %% [markdown]
# After collaberating with my group, we could not figure out how to remove null integers in their entirety. I tried filling in a space for fillna but this turned it into a string and I didn't know how to change back to integer.
#
# I created these tables in tableau to answer the questions.

# %%
# Couldn't figure out how to
X = obesity_dt[obesity_dt['Question'] == 'Percent of adults aged 18 years and older who have obesity']

fill_null = X.fillna(0)
Y = fill_null['Data_Value']

sns.distplot(Y, bins=50, kde=False)

# %% [markdown]
# This distribution is symmmetric with a media of 30% of adults, aged 18 years and older, who have obesity.

# %%
from IPython.display import Image
Image(filename="problem3.png", width=1000, height=1000)

# %% [markdown]
# # Problem 4:

# %% [markdown]
# This is wrong so I used tableau again to answer the question.

# %%
obesity_dt.plot(kind='hist', x='YearStart', y='Data_Value', bins = 100)

# %% [markdown]
# Based on this distrubtion, we can see that the US's obesity rate has increased, each year, between 2011 and 2016

# %%
Image(filename="problem4.png", width=1000, height=1000)
